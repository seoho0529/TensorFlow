# %%
# 글자 수준의 LSTM 텍스트 생성 모델 구현 - 니체의 글을 사용
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()

# path = keras.utils.get_file(
#     'rnn_short_toji.txt',
#     origin='https://github.com/pykwon/etc/blob/master/rnn_short_toji.txt')
# text = open(path).read().lower()
print('말뭉치 크기:', len(text))
# Out:
# Downloading data from https://github.com/pykwon/etc/blob/master/rnn_short_toji.txt
#    8192/Unknown - 0s 0us/step말뭉치 크기: 532328

# %%
# 60개 글자로 된 시퀀스를 추출합니다.
maxlen = 60

# 세 글자씩 건너 뛰면서 새로운 시퀀스를 샘플링합니다.
step = 3

# 추출한 시퀀스를 담을 리스트
sentences = []

# 타깃(시퀀스 다음 글자)을 담을 리스트
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('시퀀스 개수:', len(sentences))

# 말뭉치에서 고유한 글자를 담은 리스트
chars = sorted(list(set(text)))
print('고유한 글자:', len(chars))
# chars 리스트에 있는 글자와 글자의 인덱스를 매핑한 딕셔너리
char_indices = dict((char, chars.index(char)) for char in chars)

# 글자를 원-핫 인코딩하여 0과 1의 이진 배열로 바꿉니다.
print('벡터화...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# 시퀀스 개수: 177423
# 고유한 글자: 1555
# 벡터화...
# <ipython-input-3-191a0bcf48ad>:26: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
# <ipython-input-3-191a0bcf48ad>:27: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

# %%
from tensorflow.keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars)), activation='tanh'))
model.add(layers.Dense(len(chars), activation='softmax'))

optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
print(model.summary())
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               95232
#
#  dense (Dense)               (None, 57)                7353
#
# =================================================================
# Total params: 102585 (400.72 KB)
# Trainable params: 102585 (400.72 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

import random
import sys

random.seed(42)
start_index = random.randint(0, len(text) - maxlen - 1)

# 60 에포크 동안 모델을 훈련합니다
for epoch in range(1, 60):
    print('에포크', epoch)
    # 데이터에서 한 번만 반복해서 모델을 학습합니다
    model.fit(x, y, batch_size=128, epochs=1)

    # 무작위로 시드 텍스트를 선택합니다
    seed_text = text[start_index: start_index + maxlen]
    print('--- 시드 텍스트: "' + seed_text + '"')

    # 여러가지 샘플링 온도를 시도합니다
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ 온도:', temperature)
        generated_text = seed_text
        sys.stdout.write(generated_text)

        # 시드 텍스트에서 시작해서 400개의 글자를 생성합니다
        for i in range(400):
            # 지금까지 생성된 글자를 원-핫 인코딩으로 바꿉니다
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            # 다음 글자를 샘플링합니다
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# 에포크 1
# 1565/1565 [==============================] - 18s 6ms/step - loss: 2.5716
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fo the the the the the sond and and and and and and and and and and and and and and and and and of the the the the the the the sere the sond and and and and and and and in the the the and and and and and and and and and and and and and and and and and and and in the the the the the the the the the sersens and and and and whe the the the seris and and and an the the the the and the the the the the th
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fons thit of chat of the wof and he and al oud thes and the sand, and the whas and the ghengere so an the tactind and the wind astis as he the and the he piat on herinsthe the thas and and and bud in the tend sof and and and and as rand to enare chin and the ance and and and of urere sorico and an the the sthe an that and tha sters and that and of the esorathe the gof and af and ans on thece poube o
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fo horegsatis ponkacg,, ar ware
# toa thes the thaves
# aly ofojr, serurat eeve sece sfreser ar hant ef han. indewance wed ant anver, wo the aapyy oficeuw has sowhing vesit of cticn heveryter!f..
#
# tho g kemedkend wike then wof pmrollate tily thesgiag avrpeventhame]licsuf al. os uon and thite, dera as. and ally weilp
# bean fo is of im nesyfitess
# itt momperer in the shals, ehico 'overes inmcind whith afsli
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through folly obs el alladingod"
# theksppauly, wo t xh
# c ren, duli3-lof xpacarta= gow
# th vevetale hure--wulicrely whens .ushony
# e the fuciin acce sercied pxorumypoo solg we aricntichan, ,vesda , hos pohits munt
# sume onr
# unn thenctatu;-yseaun. lisg whearerse sous ]inh the r., o.v
# the epris.y, de answin antus, oac[cond bo whime: acine apr:ry
# bhoul the somnt lfosis menakl" his co litr wil-ichitiout as seltine
# 에포크 2
# 1565/1565 [==============================] - 10s 6ms/step - loss: 2.2366
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sopre the whe he ard and and and in the sere the sere the seres in the serent of the whe the whe the whe sous and and of the sore so the has and the sore the the what of the serest and in the the preas of the sere the ereat of the whis and and the seres and the seres and what of the core the what of the sore the whis the sere the whe he whe he and the in the whis whe whe s of the sous whe he
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the predist enare, are is as and sore whis whe hut the nowh the wat se praming whis whis us and wort as and senders a dowe som whin the coum mat as in ashas of se to e and war a wers and in at of the reand of mand of in and of the formes in the dore the more his and bes and and the mable dere berting the whan har und and in thar and for all able the sole the the prrouls as the the as ere far and
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fo dicvoricaty
# cowir seding
# on thet aspord he fon the in to w thel rith fred is mane s. he hat ocerud
# erdedsradstly resert ald hagl doulcversste" ées rvyis, she saos lfe bie ere kpall poente hisg wars pald of sar urle a
# dadustond a tiog mast at ar aes if pakes abbulee
# ufnas fos
# mcenacur oa to the quciivel th
#
# upe roly searry, hit wis this the
# w
# wam ham t ill
# send momegalk when
# ä tiat
# f
# ig
# the domur
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for 0elfuelet
# ar fire, to halucely : caturthd ald
# whedfrescaine ha, wr kthe that
# wire rurd?ind evens
# .kes andoltemert
# ,
# mivor datente mathe.cing--ther indeme
# wald anmerwiy hicuist hb
# e prinnon? wuo .
#  hioulmland the wedima "ut ie too
# d curion "; sutrom "abto, bur swat
# deyk ar po and empnkerp th uongrlgysy prelulq a dathe vas" mevessay tfar:
# the habv ixioued a lillew
# er fortsion. ofath isurf-upldics
# 에포크 3
# 1565/1565 [==============================] - 10s 6ms/step - loss: 2.1152
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the reand the selfere the has the sunders of the soment and the more the fore the mand of the manter and the manderse the mention the has of the berere the mantion the mand the songersertion and and the manter and anderself the manding of the sout of the more the songerser and the manter of the somand the mant of the sound the mane the somenter and the manter and and and the prouged of the somen
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for is manding antery beestune of the menderse for the menended and the suchingers, at of the maning in the has authen, ondersmout more of the hard those the rogere and and gionserss and the wand the mantions in andere the and aroughing of the matinged the hissenger and inselfing in the monition the ereathand hishendinger theas of the
# one ore the preaterely the essendition and beand thot the reane t
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for-graowiof of the has the bebtendionod to he aundenlely now wisnedre
# fucch contedy--ig ould veypriegrably-inass
# and arialestion of the
# eruat have and the nompetheys--ithinnonvertyos mntistimed alle toull" atsmenit
# insiwnopiotead ofomtthaithing thomeser seomaldidalen we hecart of hiluscaritaly. the his insigheselmencluesspay seasn, seongctef onould of the phisnalts lyloted
# mesve, whituncospiitlonge
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fore highe.bigs andy mobes ligitly
# offandcasees, sisleccoutonaal turand ithen no hapmibyuyped
# is ire"sanidgo,--stheers rowt--as" on, sloun--wathe farst, corputsoty
# soun ore hemorondy
# ringrpyertoleap.
#
# u8
# mppliolselal,ly, iexuctiog anderilged taty,--what villdive pereandisef, suliofard guysinn itinitgound.
# af iwnonchals, that rakene
# anylenite and firncmict andolisen ithercyarey hereake the arosemuner
# 에포크 4
# 1565/1565 [==============================] - 10s 6ms/step - loss: 2.0304
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the some the mant and and the silf the seat the man the mant of the some the senter and the mant of the south the mant of the fere the mant in the pround and be and of the self the self the some the sality of the self the mant in the for the self the mant of the sand and the mant of the some the mant of the mant of the sand the silf of the mant of the self and the mant of the some the some the s
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the sen the nelming the exted the falle on the frines the enting dever of the ene of the presting and and and which a dast the moral doman the forled the mere--the preat one extonent wat the cand so here be the marl the sinfule the sound the sarmed he lage there cant of the all and and ald the greation and the suge that the laad sure of a leation the mans of insored and has out the mave to there
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fon a wsed centhind thish the
# porit: fron of an make on thaur so and the mrelling, of gradis sperked unvelf,
# soul seligition wuth
# neas if,;y onoy., thee the gelle ow theer contednc toows shnol-therigal ob the the tuches now hoves vere-"of chala bleg the sty it read:, whiskeeval to ard for o hat is crausto ot ande, tand howver that the revies soom as ayd sume taaks
# thaith piss for, a sual on scaruect
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fot-wropothret be stmost?
# "m2arensunso, esaeenep s meve sume dute,
# eatize--thete t wheil, spay,
# whor oé ho siude it mote.
# a toit cruth
# certaknars anm amkerr
# factss3es dof. theygebllationon ow a inscive
# as "ree--ir in hele powigay of"sef omablure penand-thal oug ha
# mustnesal and tren in
# deve-the,
# en prion bary
# of maakkeypre,
# igroucte, virco im"capte that of soict :
# al-"care.=--hm chered. in capetraur
# 에포크 5
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.9617
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the fore and the propestion of the fare of the fare of the sention of the fore the stinterition of the manting the pricines and its a the freate of the somation of the fare of the manting of the will of the fore and the beland the fore and the manter the fare of the sencering the mant the reast of the for the condering the proloss and the mant in the beling the prolost of the will of the propes
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fore of chactions as a song the hy songere of has in the enistence which so his ran in which it phisespice of then the lore in of this from a whor
# the fores and the and to which in thing the pain the mast which the enfertion and blough which as berong the preand his and the preate of the fare in the religes of the geal to nee some the sayplition of and the casting the priliged the righing spond the
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for heling too
# elopal--treabperater be alleques. the preats of: deenching in abfomeligust and
# of vinkanetiouty ispeits theneghat, age antind.
#
#
# 1v] the fore thace suchimo of sthinkso, acknaliperes. gode and fererwiod ter the weres of senger this miverratives,
# paselivigat crivinlobiding (rlavey varthated
# ane intt cand parair, be nor tould it poinh theprefianains of thim the pime ilvaline of tualiness
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for "thisk rivobuenifo at
# =anfims, os tleshged dowing anfous ha k7y"phelowi2e the racint one weanbly
# greal
# wxilvok---uspelost the
# "upregsamine, the h'nstunchim for mtelf or
# the jond
# agicimatomacazerwat croinier
# feastion, is theciman
# senworifer--itemore fuct fivnoventa,
# the sigmong of mnescredtianlyce ofow yobes of the infurefulitugios befwics
# of thim vtree-ser, bity a questco ofabiluless, in blevel.
# 에포크 6
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.9034
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the searing and the sention of the some the senter and the some the sent in the sention and the man the man in the sention of the some the such and the sen the say the senting and the senting and and the man in the say the some the senters of the sention of the selfer and the self the sengrest of the some the some the seation of the menter of the sention of the sent the prost the free the sentin
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for to extans and in the pote and the pare of the some the hand of that the pish is ond ene such and it man in the greach whither in the fore and naturing and evor the are the its it is distine the conself the man the induling and the self the sense promose and the men prean and will ene sunder them the sountes and bewing that the manter the say and such all good him eare that the perare to mone for
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fon of a raif, a weel
# hive thene nom debarugon, craves, withto lomger"
# prones and yevery one be a the sents stilling, and mangers.
#  1rey and masty of ints even, sarue for aging of susfuctling thain hat le in also the evils, whihis sutim as may there anchan even ather that thim
# it that thes stonc sposicay
# imnans a and
# hufon mist decione, no muburies in leatade that is rywer phelable the
# more his the
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foo and anl blesing ake, shain's mor owaraty, at"-o
# motig7t word, the feifathy avrerue themmawhes fummen thim
# ein; the lreeanstulos, reand ritopsess ofite ald necess, of corman mentery[paticy awnomke, enewnyim tines. for tist
# gilg erniverunyss? ilidgresæs, these thole en.
#
# . if t_un she many his fee mersiding rapkerowion: is nowiked wioblom the sthom tiken; to acreviited while perale myseef by they
#
# 에포크 7
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.8533
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the senter and the sense of the some the senter and the singress of the sentiness of the sense of the some the such the sender and the sender and the such a man the sentiness of the senting the sense of the some and the sentiness of the senting the some of the sention of the senting the sentiness of the stree the sention of the self the sempless of the self conservent of the sensere of the sense
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the sentions of the postivily, the sey aushans and consernated and propest desernist and stiming--and can to the sone has onters--the some the selfect strater and and ever the more of the dering the same his dotert and strode a deant and stinder and the sack of inself for the exen the stome has be the is not man as a sole and plows to men in the the stree still notrert of the pristious the maste
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fore
# neil. undirhers and aluach the manoniscon's to for the goid
# ond
# pleare.
#
# 1ne
#  that nee defibit of tiench--but
# antable bequent, asugilizes a
# enesangatiom,. knowes" othimpeliable some wa to that mastie more be woll, the reger
# xyectart
# buhand reals, to "unableanth
# like and cuntinest
# in then
# alsed atterstorus.
#
# b1ust the not
# they is in, stin suchanes hind allugor the say the stiph, with a the wonl
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foll exrar to nay haten, ;pinas
# him might"
# ir out a renwiothenc;g, herod
# e on)
# that te sioquil--itseles spitire alleble of the way accomest wor myasiteaps the cinccioulmation. on fa toutlo ants friseld. o tanber in!
#
# 1he trem.n,
# to ranelly, hys." he
# it as ferilre bist pardicts? privorerie to or paties.
#
#  nt
#  x t ic mo)
# pricl. ho knother sule?s"
# it aushas mengrabwe, thnis to lead:
#
# c radicus is
# alsh
# 에포크 8
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.8107
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the faction of the same the which of the conservent of the self--it is the fact of the self-indersely and the self-inderserves of the some the condicient of the sention of the prosed and the seare and the sention of the self-incersernal the manter and the incomented the self-indingeration of the sense of the same the histering the every of the warther the sentions of the man in the incomented an
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through foolle as a sensered that is a man but bether a will of the heligions, the fare of a mustives and whome in that the world has and he incomerted that relight of the exisience, is the weally of the concerie and there is its lowe the tile of the erear the strace of the the master and there and
# course of the concelied as the simence and the selficiences of may his of the incerdinction of the propeding t
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for shilares a mokeropaded and wille's sbutinjises any awsoby that wholepawhy: wouch the
# wamint of mustliecl were imsed, is inercarience, aposed,
# is all ansigetnorivate, be a maburs! the orgmact andiss our scesperingial themeknobur the, andering to scoule of the hidvery examure
# in have
# dustatencions
# pare hat
# out is mentary" obvioning are is thithifed conliiratiens onchome that every, absespeentr ind
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forlity--the in-mase have beeustin of gervely inselofrol coust--at acteach, and, fur cage, a9nerdg tandanader withor ard the chisht so idrerersat: bionosicilitl, at constincteruler aln lisgpwery
# of the
# made, as
# incomertule. there, fai, himar, deawudedy, and
# indtifaturesuy inverdens--it preopent wisedvite of an3y orighul the toughains
# a7tuid,"-insmatome and gloptates are undelobienceint of whikes ae
# 에포크 9
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.7731
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the some of the consention of the some the farth the stronged the falle of the expection of the sempless of the sense of the sense of the something and the sense of the sense of the something the compless of the conter the condection of the some the senter of the sense of the fore of the manger and the prosting the sense of the some the constion and something the self the sense of the sense of t
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the will youl sye in the well conservent be the fores and the may some of the intalle
# the hame to commont distingless and more men existing that the greatice the many not menelally the still the good and bith out of he hear and the
# serther thein is sterd has the sense and stomathy and the sact of the nelled pertous, and the parthing in the consected the condect of we the one belows condined the
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forkast cerieforo, yough in unore with
# a luthous madili.
# in divanicy ippately the bas, of the phrogiticeact allach solith re deathing and ackmone he existable beynted houth defelt--us reghericoussen's fould
# adumanter, furch oug men to nasurm the cupticl
# self quals, the ince the dearyt which as to besuro, even agence, is as
# f chirses im it haw ewxish
# supecharition
# of dear to may, willaces is
# intrune
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foo deedicacc asibeate of hattine'
#
# [ol--calling, he was bling wiscadhy wuther; of throlagred,
# philosultushs justapsing becisinouses--humalopeagl: which theizary is
# mereliesir duult: feeh sentsing (owiver it bright, becemen at a they from fraldis sempla commal hage mime the pothing, pleake's we loge face and intomet the danged the greaty dopuble dofikicl, to demidicake m ouls.--he hear
#  wild humant
# 에포크 10
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.7396
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the such and some the such and such a man and the such and the sense of the suct and in the conselfer the such a man who have the sense of the such and the such a man who have the such and some the sense of the such a man with the sense of the such and the suct and such a more of the some the such and the some the such and most of the sense of the sense of the such a may be the sens
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for distonce in the wart have of the erist to congrited for the such how are some the man in hame such of must and soul soce it way so may be all the incrutuct and have not the should restinations and leverman to has dowed bere in the suce to sempress and science and strengeral such a munds amarulated has been must the some that is and the some a mone of the still to presond to prinder of the since
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for in all what al ander a
# melater in the bllys, than
# is very
# delso men churosis of chural songidally-to the retigent leatiwiog. don of a now of thay destint; a love
# hmor the before of suchre, angous that wisce, hay lof, the mcamand--chilfop fromly detrunce of sicess of "thinkeran
#
# fagrnohile arrulity of sentiment
# afleedad conmonslys verises nor
# in ord great tray conclually--obed desiluterandeds var
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through former aw regaint and graent heard, imioner cits sughase gund; it wnot arxapucal will
# witl poirbal
# inligitanionterming of bounk cyousc and morlatien, owhnducle]sh as: a for the
# soll read onch, wholl compon eare philosophenears with rejnlicterest, cauree, adr all arren's cencol)ly that i rrautams de gowaring expecys eathing of cimnifne accnention
# withind, the
# pronoundesed wiblly
# ageprows, to bo alss"
# 에포크 11
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.7096
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the man and the strong and the sense of the streng of the sense of the will a man and still the sense of such a man and the spirit of the self the such a more so in a man we come a man with the still the self of the same the sense of the sense of the sense of the such and the such a man in the self of the strong the same a man with the sense of the sense of the semple of the man in the self the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the wart man so the strong mode the man lited the seloge of the soul as a sumple to a mode happer of serfinemonater and the hast precapions with it as it is its itself of the religious and something, to any conridience of every such a mangation and the saypowally the religion of himself the sangeral were in the spirit the waste not such a coneral to and reast to it is a man more the condicaling
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for fide'
# aus, and somek. any hurdone hand apply!cien cautized
# ard goor hemo at gesserving in wrock and hom with in
# meghly were be id
# pilier his as it ardingthands grounning lovowhry be who way beand a soul rebelt we las langs to doman that fas a heng its but be itself spirit as firse pain wowlate at meaghing, hure" eistinanderelable and word oubleate the free hioks, the limmoly. they a say in d oul
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for expecme abtiol destruby stitusu.
#
# hewis or minking the:) the insuall
# cercousse crans that
# it phelopvanty, flamould lun
# welloäg which rabitian" beingnts undtimin:--our
# thes for that as ho ligic of man, a lowndgn
# man. dowe ty,.
#
#
# 1c
# "vore one, "very oarrious but phinonable vir;" wish
# yo spirbeo!
#
# 9o he necess! hif
# concomer
# as a what imment, abdornibre andil, everyrmation of
# alvists ou sonective
# xe
# 에포크 12
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.6830
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the sense of the sense of the sense of the self of the sense of the sense of the master and something of the sense of the sense of man and man in the sense of the sense of the sense of the really and moral to the sense of the sense of the sense of the sense of the seals and the strenged and something the self contration of the sense of a man in the sense of the sense of the sense of
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the sense of the more can on the general and it is as in the were have disternest and diblective in the langect desirtances of lifelity, and the one something that as in the relect, for the fail of the deligial staps of the great how such and respict to be to the sopething in the gonders of the sense of man agong such ression on the now which the last and the worst of merile, and sense of accoun
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for the necms man ry concence of the implation
# to boligut moral ponled, and rasions thing donsiviout, as sense space; but now relvess are soud taked the masign trad
# brogally some of the biding to the incemplance, prove-flee niffirned of the bart hare to airs, and imstance! a paspursible, and inclear and
# andtranded everythero"mand
# do pleapaticy and , all to but by
# nechard more the great to nutaritial
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forcignted,"-
# t1a land e3tly deid, achimations and with geald eppeoss. tror
# event of thom indoristly domed mettrater,
# hy iznoodognouly--the
# begeat man we longer before
# rnof rave, an podsible, a poil sence, shimm now"dinghwila whrims
# quended that is on an acciamn exen centurres serres youchide-himsed dalanting "mhand rewiticls all, thre' may foral hawnist"n
# of himsals
# by different, "sweat of tho bit
# 에포크 13
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.6587
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the sense of the from the sense of the feel man and the sense of the man who have not to be and the sense of the sense of the sense of the same the man in the proped the consented the man who have the man who have the more the man who have the man which a man and more and the intermanition of the farture of the falue of the sense of the conter and concersion of the precession of the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the condition and preception of the resule. the existention of semiences. the ond and the destance of cruticist conception who and sense of the farour and most to the great men, he waste, without of the still still as a the man which is and chatest find of the complest who and beter and conceptional he sthe the himself in the waration, man the men in himself of the conderserves who have and can
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foring and puticed, all the
# fore's matter to be-asy
# regard arame, inselvens of hear: to gave:
# obtare for thou mere: it is not bauce, inaght as a gloe and gair
# of intared in pheregious with simple, and theortriese scarisedis, the dewer, of
# the instainy. "tro
# the mett it
# dasteredous is accormes on which is would
# batth to as the
# sand persende. the serpeef--of
# conminers to have beeves asten every aclife
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for to ten evone and, howaditger, angore with ame, one manoud
# to the aff whates or ustrout curtrifulted--immad of stermer heagater viedical
# in the would
# neguisted came whathdre was
# and detrligement
# itsssing van), the saured therevilaict to
#
# eprearned secusiticn l'adity in
# gedeace, this
# exsercable andiming, i pleesial sare parved his
# personing asmong as art
# of hour what dsple thrubf wave, and im plev
# 에포크 14
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.6369
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the some the sensition of the fact the sense of the such an and the same to the sense of the something to the fact the strong of the fact the sense of the sense of the sense of the sense of the sense of the good man with the sense of the sense of the such a man in the forme the sense of the same of the sense of the sense of the fact to the sense of the constination of the good and the sensition
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the distrand of all in the goodment that in and have of the philosophers, and berongering
# to man
# in every sand that there is concerned to be the same this the condution of the whole mind respard to caush as the believe the sense of liveredic of the faither
# word of the man, in the preater and accordans of the signess of the consiferent, and and in a purtual discretion and can a hand of the marily
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fould bad to its this hand cooldy ons not weaks and restont, that or creast also whinesy and imponating do mur be vorsane in ristance of nomaliticus ofints is and daugl
# attell, throogich to longs,
# as
# seconsland
# also--a dee has loon to actsubenged the general tr?o upants fact of was agter of
# gorman appry.s "if certarn plarmentar into promptious
# and an highest can at intails sears dood in aboun bet si
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for theroufly trorgh. i veny to mind
# 1an whater, free
# no heary deæilally.
#
# 1o peow alloglon he aral yen like liti[smand bide bedeater profterknanitys purtimint that mori gnailt? a difucitufly
# but hishenicary of tights, stillikes,
# a funler jnymse as becounsur gainical and: goecily! a
# vookingss hyponed, isenary
# ronobless truam-nupt]s moru[g, inde, take ward imntiinaty to injuvequent, regard:--i  lowe
# 에포크 15
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.6166
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the discomptive
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-a72531fac900> in <cell line: 16>()
#      37
#      38             # 다음 글자를 샘플링합니다
# ---> 39             preds = model.predict(sampled, verbose=0)[0]
#      40             next_index = sample(preds, temperature)
#      41             next_char = chars[next_index]
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2594                     )
#    2595
# -> 2596             data_handler = data_adapter.get_data_handler(
#    2597                 x=x,
#    2598                 batch_size=batch_size,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in get_data_handler(*args, **kwargs)
#    1686             return _ClusterCoordinatorExactEvalDataHandler(*args, **kwargs)
#    1687         return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1688     return DataHandler(*args, **kwargs)
#    1689
#    1690
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute, pss_evaluation_shards)
#    1290
#    1291         adapter_cls = select_data_adapter(x, y)
# -> 1292         self._adapter = adapter_cls(
#    1293             x,
#    1294             y,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     353         indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     354
# --> 355         dataset = self.slice_inputs(indices_dataset, inputs)
#     356
#     357         if shuffle == "batch":
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in slice_inputs(self, indices_dataset, inputs)
#     394             )
#     395
# --> 396         dataset = dataset.map(grab_batch, num_parallel_calls=tf.data.AUTOTUNE)
#     397
#     398         # Default optimizations are disabled to avoid the overhead of
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/dataset_ops.py in map(self, map_func, num_parallel_calls, deterministic, name)
#    2266     # pylint: disable=g-import-not-at-top,protected-access
#    2267     from tensorflow.python.data.ops import map_op
# -> 2268     return map_op._map_v2(
#    2269         self,
#    2270         map_func,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/map_op.py in _map_v2(input_dataset, map_func, num_parallel_calls, deterministic, name)
#      38         input_dataset, map_func, preserve_cardinality=True, name=name)
#      39   else:
# ---> 40     return _ParallelMapDataset(
#      41         input_dataset,
#      42         map_func,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/map_op.py in __init__(self, input_dataset, map_func, num_parallel_calls, deterministic, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#     146     self._input_dataset = input_dataset
#     147     self._use_inter_op_parallelism = use_inter_op_parallelism
# --> 148     self._map_func = structured_function.StructuredFunctionWrapper(
#     149         map_func,
#     150         self._transformation_name(),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     263         fn_factory = trace_tf_function(defun_kwargs)
#     264
# --> 265     self._function = fn_factory()
#     266     # There is no graph to add in eager mode.
#     267     add_to_graph &= not context.executing_eagerly()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in get_concrete_function(self, *args, **kwargs)
#    1220   def get_concrete_function(self, *args, **kwargs):
#    1221     # Implements GenericFunction.get_concrete_function.
# -> 1222     concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1223     concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1224     return concrete
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1190       if self._variable_creation_config is None:
#    1191         initializers = []
# -> 1192         self._initialize(args, kwargs, add_initializers_to=initializers)
#    1193         self._initialize_uninitialized_variables(initializers)
#    1194
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _initialize(self, args, kwds, add_initializers_to)
#     692     )
#     693     # Force the definition of the function for these arguments
# --> 694     self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     695         args, kwds, self._variable_creation_config
#     696     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in trace_function(args, kwargs, tracing_options)
#     176       kwargs = {}
#     177
# --> 178     concrete_function = _maybe_define_function(
#     179         args, kwargs, tracing_options
#     180     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _maybe_define_function(args, kwargs, tracing_options)
#     282         else:
#     283           target_func_type = lookup_func_type
# --> 284         concrete_function = _create_concrete_function(
#     285             target_func_type, lookup_func_context, func_graph, tracing_options
#     286         )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     306     )
#     307
# --> 308   traced_func_graph = func_graph_module.func_graph_from_py_func(
#     309       tracing_options.name,
#     310       tracing_options.python_function,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1057
#    1058     _, original_func = tf_decorator.unwrap(python_func)
# -> 1059     func_outputs = python_func(*func_args, **func_kwargs)
#    1060
#    1061     # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in wrapped_fn(*args, **kwds)
#     595         # the function a weak reference to itself to avoid a reference cycle.
#     596         with OptionalXlaContext(compile_with_xla):
# --> 597           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     598         return out
#     599
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py in wrapped_fn(*args)
#     230       def wrapped_fn(*args):  # pylint: disable=missing-docstring
#     231         ret = wrapper_helper(*args)
# --> 232         ret = structure.to_tensor_list(self._output_structure, ret)
#     233         return [ops.convert_to_tensor(t) for t in ret]
#     234
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/util/structure.py in to_tensor_list(element_spec, element)
#     409   # pylint: disable=protected-access
#     410   # pylint: disable=g-long-lambda
# --> 411   return _to_tensor_list_helper(
#     412       lambda state, spec, component: state + spec._to_tensor_list(component),
#     413       element_spec, element)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/util/structure.py in _to_tensor_list_helper(encode_fn, element_spec, element)
#     360
#     361   return functools.reduce(
# --> 362       reduce_fn, zip(nest.flatten(element_spec), nest.flatten(element)), [])
#     363
#     364
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/util/nest.py in flatten(structure)
#      40
#      41 def flatten(structure):
# ---> 42   return nest_util.flatten(nest_util.Modality.DATA, structure)
#      43
#      44
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in flatten(modality, structure, expand_composites)
#     716
#     717
# --> 718 def flatten(modality, structure, expand_composites=False):
#     719   """Flattens a nested structure.
#     720
#
# KeyboardInterrupt:
